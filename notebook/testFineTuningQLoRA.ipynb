# %%
# %%capture
# !pip install datasets;
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7;

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
# The model that you want to train from the Hugging Face hub
model_name = "NousResearch/Llama-2-7b-chat-hf"

# The instruction dataset to use
dataset_name = "cungnlp/sample_datacung"

# Fine-tuned model name
new_model = "llama-2-7b-cungnlp"

# %%
################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 1

# Batch size per GPU for evaluation
per_device_eval_batch_size = 1

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine)
lr_scheduler_type = "constant"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 2

# Log every X updates steps
logging_steps = 2

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
# Load dataset (you can process it here)
dataset = load_dataset(dataset_name, split="train")

# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# Downloading readme:   0%|          | 0.00/263 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/3.43k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/10 [00:00<?, ? examples/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:25, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>2.205300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.758400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.247900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.946000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.729500</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(

# %%
# # Run text generation pipeline with our next model
# prompt = "Tiền thân của Trường Đại học Xây dựng là gì? "
# pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
# result = pipe(f"[INST] {prompt} [/INST]")
# print(result[0]['generated_text'])

# %%
torch.cuda.empty_cache()

# %%
# !zip -r llama-2-7b-cungnlp.zip results llama-2-7b-cungnlp
# Out:
#   adding: results/ (stored 0%)
#   adding: results/checkpoint-10/ (stored 0%)
#   adding: results/checkpoint-10/training_args.bin (deflated 50%)
#   adding: results/checkpoint-10/tokenizer.json (deflated 74%)
#   adding: results/checkpoint-10/special_tokens_map.json (deflated 72%)
#   adding: results/checkpoint-10/adapter_model.bin (deflated 8%)
#   adding: results/checkpoint-10/trainer_state.json (deflated 66%)
#   adding: results/checkpoint-10/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-10/README.md (deflated 66%)
#   adding: results/checkpoint-10/scheduler.pt (deflated 58%)
#   adding: results/checkpoint-10/tokenizer_config.json (deflated 67%)
#   adding: results/checkpoint-10/adapter_config.json (deflated 43%)
#   adding: results/checkpoint-10/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-6/ (stored 0%)
#   adding: results/checkpoint-6/training_args.bin (deflated 50%)
#   adding: results/checkpoint-6/tokenizer.json (deflated 74%)
#   adding: results/checkpoint-6/special_tokens_map.json (deflated 72%)
#   adding: results/checkpoint-6/adapter_model.bin (deflated 8%)
#   adding: results/checkpoint-6/trainer_state.json (deflated 59%)
#   adding: results/checkpoint-6/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-6/README.md (deflated 66%)
#   adding: results/checkpoint-6/scheduler.pt (deflated 58%)
#   adding: results/checkpoint-6/tokenizer_config.json (deflated 67%)
#   adding: results/checkpoint-6/adapter_config.json (deflated 43%)
#   adding: results/checkpoint-6/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-8/ (stored 0%)
#   adding: results/checkpoint-8/training_args.bin (deflated 50%)
#   adding: results/checkpoint-8/tokenizer.json (deflated 74%)
#   adding: results/checkpoint-8/special_tokens_map.json (deflated 72%)
#   adding: results/checkpoint-8/adapter_model.bin (deflated 8%)
#   adding: results/checkpoint-8/trainer_state.json (deflated 63%)
#   adding: results/checkpoint-8/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-8/README.md (deflated 66%)
#   adding: results/checkpoint-8/scheduler.pt (deflated 58%)
#   adding: results/checkpoint-8/tokenizer_config.json (deflated 67%)
#   adding: results/checkpoint-8/adapter_config.json (deflated 43%)
#   adding: results/checkpoint-8/rng_state.pth (deflated 25%)
#   adding: results/runs/ (stored 0%)
#   adding: results/runs/Dec11_16-47-19_0adb1ebb14c4/ (stored 0%)
#   adding: results/runs/Dec11_16-47-19_0adb1ebb14c4/events.out.tfevents.1702313248.0adb1ebb14c4.410.0 (deflated 59%)
#   adding: results/checkpoint-2/ (stored 0%)
#   adding: results/checkpoint-2/training_args.bin (deflated 50%)
#   adding: results/checkpoint-2/tokenizer.json (deflated 74%)
#   adding: results/checkpoint-2/special_tokens_map.json (deflated 72%)
#   adding: results/checkpoint-2/adapter_model.bin (deflated 10%)
#   adding: results/checkpoint-2/trainer_state.json (deflated 47%)
#   adding: results/checkpoint-2/optimizer.pt (deflated 7%)
#   adding: results/checkpoint-2/README.md (deflated 66%)
#   adding: results/checkpoint-2/scheduler.pt (deflated 58%)
#   adding: results/checkpoint-2/tokenizer_config.json (deflated 67%)
#   adding: results/checkpoint-2/adapter_config.json (deflated 43%)
#   adding: results/checkpoint-2/rng_state.pth (deflated 25%)
#   adding: results/checkpoint-4/ (stored 0%)
#   adding: results/checkpoint-4/training_args.bin (deflated 50%)
#   adding: results/checkpoint-4/tokenizer.json (deflated 74%)
#   adding: results/checkpoint-4/special_tokens_map.json (deflated 72%)
#   adding: results/checkpoint-4/adapter_model.bin (deflated 8%)
#   adding: results/checkpoint-4/trainer_state.json (deflated 54%)
#   adding: results/checkpoint-4/optimizer.pt (deflated 8%)
#   adding: results/checkpoint-4/README.md (deflated 66%)
#   adding: results/checkpoint-4/scheduler.pt (deflated 58%)
#   adding: results/checkpoint-4/tokenizer_config.json (deflated 67%)
#   adding: results/checkpoint-4/adapter_config.json (deflated 43%)
#   adding: results/checkpoint-4/rng_state.pth (deflated 25%)
#   adding: llama-2-7b-cungnlp/ (stored 0%)
#   adding: llama-2-7b-cungnlp/adapter_model.bin (deflated 8%)
#   adding: llama-2-7b-cungnlp/README.md (deflated 40%)
#   adding: llama-2-7b-cungnlp/adapter_config.json (deflated 43%)

# %%
# !mv llama-2-7b-cungnlp.zip /content/drive/MyDrive/Model

# %%
# !unzip /content/drive/MyDrive/Model/llama-2-7b-cungnlp.zip -d .
# Out:
# Archive:  /content/drive/MyDrive/Model/llama-2-7b-cungnlp.zip
#    creating: ./results/
#    creating: ./results/checkpoint-10/
#   inflating: ./results/checkpoint-10/training_args.bin
#   inflating: ./results/checkpoint-10/tokenizer.json
#   inflating: ./results/checkpoint-10/special_tokens_map.json
#   inflating: ./results/checkpoint-10/adapter_model.bin
#   inflating: ./results/checkpoint-10/trainer_state.json
#   inflating: ./results/checkpoint-10/optimizer.pt
#   inflating: ./results/checkpoint-10/README.md
#   inflating: ./results/checkpoint-10/scheduler.pt
#   inflating: ./results/checkpoint-10/tokenizer_config.json
#   inflating: ./results/checkpoint-10/adapter_config.json
#   inflating: ./results/checkpoint-10/rng_state.pth
#    creating: ./results/checkpoint-6/
#   inflating: ./results/checkpoint-6/training_args.bin
#   inflating: ./results/checkpoint-6/tokenizer.json
#   inflating: ./results/checkpoint-6/special_tokens_map.json
#   inflating: ./results/checkpoint-6/adapter_model.bin
#   inflating: ./results/checkpoint-6/trainer_state.json
#   inflating: ./results/checkpoint-6/optimizer.pt
#   inflating: ./results/checkpoint-6/README.md
#   inflating: ./results/checkpoint-6/scheduler.pt
#   inflating: ./results/checkpoint-6/tokenizer_config.json
#   inflating: ./results/checkpoint-6/adapter_config.json
#   inflating: ./results/checkpoint-6/rng_state.pth
#    creating: ./results/checkpoint-8/
#   inflating: ./results/checkpoint-8/training_args.bin
#   inflating: ./results/checkpoint-8/tokenizer.json
#   inflating: ./results/checkpoint-8/special_tokens_map.json
#   inflating: ./results/checkpoint-8/adapter_model.bin
#   inflating: ./results/checkpoint-8/trainer_state.json
#   inflating: ./results/checkpoint-8/optimizer.pt
#   inflating: ./results/checkpoint-8/README.md
#   inflating: ./results/checkpoint-8/scheduler.pt
#   inflating: ./results/checkpoint-8/tokenizer_config.json
#   inflating: ./results/checkpoint-8/adapter_config.json
#   inflating: ./results/checkpoint-8/rng_state.pth
#    creating: ./results/runs/
#    creating: ./results/runs/Dec11_16-47-19_0adb1ebb14c4/
#   inflating: ./results/runs/Dec11_16-47-19_0adb1ebb14c4/events.out.tfevents.1702313248.0adb1ebb14c4.410.0
#    creating: ./results/checkpoint-2/
#   inflating: ./results/checkpoint-2/training_args.bin
#   inflating: ./results/checkpoint-2/tokenizer.json
#   inflating: ./results/checkpoint-2/special_tokens_map.json
#   inflating: ./results/checkpoint-2/adapter_model.bin
#   inflating: ./results/checkpoint-2/trainer_state.json
#   inflating: ./results/checkpoint-2/optimizer.pt
#   inflating: ./results/checkpoint-2/README.md
#   inflating: ./results/checkpoint-2/scheduler.pt
#   inflating: ./results/checkpoint-2/tokenizer_config.json
#   inflating: ./results/checkpoint-2/adapter_config.json
#   inflating: ./results/checkpoint-2/rng_state.pth
#    creating: ./results/checkpoint-4/
#   inflating: ./results/checkpoint-4/training_args.bin
#   inflating: ./results/checkpoint-4/tokenizer.json
#   inflating: ./results/checkpoint-4/special_tokens_map.json
#   inflating: ./results/checkpoint-4/adapter_model.bin
#   inflating: ./results/checkpoint-4/trainer_state.json
#   inflating: ./results/checkpoint-4/optimizer.pt
#   inflating: ./results/checkpoint-4/README.md
#   inflating: ./results/checkpoint-4/scheduler.pt
#   inflating: ./results/checkpoint-4/tokenizer_config.json
#   inflating: ./results/checkpoint-4/adapter_config.json
#   inflating: ./results/checkpoint-4/rng_state.pth
#    creating: ./llama-2-7b-cungnlp/
#   inflating: ./llama-2-7b-cungnlp/adapter_model.bin
#   inflating: ./llama-2-7b-cungnlp/README.md
#   inflating: ./llama-2-7b-cungnlp/adapter_config.json

# %%
# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map={"": 0},
)
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()
# Out:
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
# Out:
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/cungnlp/llama-2-7b-cungnlp/commit/01174df8e31d5cffeafc0d86ea3dc569781af064', commit_message='Upload tokenizer', commit_description='', oid='01174df8e31d5cffeafc0d86ea3dc569781af064', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Run text generation pipeline with our next model
prompt = "Tiền thân của Trường Đại học Xây dựng là gì? "
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(f"[INST] {prompt} [/INST]")
print(result[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# [INST] Tiền thân của Trường Đại học Xây dựng là gì?  [/INST]  Trường Đại học Xây dựng được thành lập năm 1956, trước đó có tên gọi là Trường Cao đẳng Xây dựng, được thành lập năm 1945 bởi Chính phủ Cách mạng Lâm thời.
#
# Trường Cao đẳng Xây dựng được thành lập với mục đích đào tạo cán bộ
